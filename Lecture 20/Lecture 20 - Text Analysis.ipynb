# %% [markdown]
# # <span style="color:darkblue"> Lecture 20: Text Analysis </span>
#
# <font size = "5">
#
# Intro text analysis
#
# https://www.youtube.com/watch?v=IRKDrrzh4dE

# %% [markdown]
# # <span style="color:darkblue"> I. Setup Working Environment </span>

# %%
# Import SK-Learn library for machine learning functions
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS 
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split



# Import standard data analysis packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import Kmenas
from sklearn.cluster import MiniBatchKMeans

import faiss
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # <span style="color:darkblue"> II. Data </span>
#
# <font size = "5">
#
# We will analyze a dataset on Amazon Reviews
#
# https://www.kaggle.com/datasets/yasserh/amazon-product-reviews-dataset/data

# %%
data = pd.read_csv("data_raw/amazon_reviews.csv")

len(data)
# Out:
# 1597

# %% [markdown]
# <font size = "5">
#
# Check features

# %%
data.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'dateAdded',
#        'dateUpdated', 'dimension', 'ean', 'keys', 'manufacturer',
#        'manufacturerNumber', 'name', 'prices', 'reviews.date',
#        'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating',
#        'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.userCity', 'reviews.userProvince', 'reviews.username', 'sizes',
#        'upc', 'weight'],
#       dtype='object')

# %% [markdown]
# <font size = "5">
#
# Check text

# %%
reviews = data["reviews.text"]

# %% [markdown]
# <font size = "5">
#
# Check rating

# %%
plt.hist(x = data["reviews.rating"])
# Out:
# (array([ 42.,   0.,  34.,   0.,   0., 124.,   0., 236.,   0., 741.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <font size = "5">
#
# Filter non-missing ratings data
#
# - 26% missing data!
# - Could generate selection bias in reviews

# %%
# Check for missing values
# A lot of reviews are missing review data
missing_values = data["reviews.rating"].isnull().sum()
percent_missing = missing_values /len(data)
print(percent_missing)

# Extract non-missing data
data_nonmissing = data[data["reviews.rating"].notnull()]
# Out:
# 0.2629931120851597

# %% [markdown]
# # <span style="color:darkblue"> III. Bag of Words </span>

# %% [markdown]
# <font size = "5">
#
# Stop words
#
# - Commonly used words
# - Available for different languages

# %%
# First ten English stop words
list(ENGLISH_STOP_WORDS)
# Out:
# ['cant',
#  'for',
#  'please',
#  'if',
#  'become',
#  'is',
#  'mine',
#  'than',
#  'part',
#  'during',
#  'nor',
#  'third',
#  'only',
#  'whole',
#  'amoungst',
#  'a',
#  'such',
#  'hereafter',
#  'out',
#  'been',
#  'inc',
#  'interest',
#  'thereby',
#  'nowhere',
#  'whereas',
#  'thick',
#  'whose',
#  'detail',
#  'within',
#  'afterwards',
#  'anywhere',
#  'through',
#  'via',
#  'anything',
#  'whence',
#  'whereafter',
#  'per',
#  'already',
#  'between',
#  'less',
#  'besides',
#  'among',
#  'name',
#  'beside',
#  'ltd',
#  'nine',
#  'from',
#  'everywhere',
#  'former',
#  'nobody',
#  'two',
#  'see',
#  'mostly',
#  'side',
#  'itself',
#  'seeming',
#  'perhaps',
#  'seems',
#  'him',
#  'serious',
#  'would',
#  'themselves',
#  'always',
#  'hasnt',
#  'move',
#  'then',
#  'twelve',
#  'next',
#  'too',
#  'something',
#  'wherever',
#  'being',
#  'i',
#  'take',
#  'neither',
#  'whereby',
#  'much',
#  'their',
#  'made',
#  'moreover',
#  'none',
#  'it',
#  'almost',
#  'yours',
#  'hereby',
#  'us',
#  'no',
#  'while',
#  'system',
#  'thin',
#  'because',
#  'somehow',
#  'about',
#  'otherwise',
#  'however',
#  'few',
#  'hence',
#  'sometimes',
#  'fifty',
#  'well',
#  'rather',
#  'as',
#  'her',
#  'put',
#  'yourself',
#  'all',
#  'beyond',
#  'others',
#  'last',
#  'full',
#  'someone',
#  'get',
#  'to',
#  'whatever',
#  'seem',
#  'herein',
#  'whither',
#  'ours',
#  'onto',
#  'thus',
#  'several',
#  'not',
#  'indeed',
#  'he',
#  'across',
#  'describe',
#  'mill',
#  'elsewhere',
#  'except',
#  'fifteen',
#  'behind',
#  'yet',
#  'again',
#  'they',
#  'upon',
#  'might',
#  'any',
#  'forty',
#  'sixty',
#  'down',
#  'has',
#  'in',
#  'although',
#  'cry',
#  'still',
#  'but',
#  'wherein',
#  'until',
#  'due',
#  'towards',
#  'around',
#  'further',
#  'ten',
#  'can',
#  'must',
#  'whereupon',
#  'throughout',
#  'nothing',
#  'were',
#  'and',
#  'there',
#  'could',
#  'latter',
#  'eight',
#  'under',
#  'one',
#  'some',
#  'the',
#  'four',
#  'against',
#  'am',
#  'everyone',
#  'own',
#  'who',
#  'where',
#  'once',
#  'con',
#  'you',
#  'whether',
#  'becomes',
#  'other',
#  'bill',
#  'ever',
#  'off',
#  'since',
#  'at',
#  'this',
#  'together',
#  'them',
#  'into',
#  'herself',
#  'up',
#  'me',
#  'co',
#  'with',
#  'both',
#  'else',
#  'myself',
#  'therein',
#  'hers',
#  'many',
#  'therefore',
#  'do',
#  'even',
#  'be',
#  'empty',
#  'first',
#  'whenever',
#  'often',
#  'should',
#  'find',
#  'though',
#  'those',
#  'beforehand',
#  'more',
#  'anyhow',
#  'himself',
#  'very',
#  'how',
#  'on',
#  'our',
#  'amongst',
#  'noone',
#  'when',
#  'meanwhile',
#  'whom',
#  'was',
#  'here',
#  'or',
#  'found',
#  'became',
#  'she',
#  'so',
#  'call',
#  'also',
#  'above',
#  'somewhere',
#  'top',
#  'anyone',
#  'eg',
#  'hundred',
#  'never',
#  'hereupon',
#  'have',
#  'your',
#  'un',
#  'had',
#  'alone',
#  'give',
#  'which',
#  'thereupon',
#  'de',
#  'below',
#  'without',
#  'are',
#  'least',
#  'sometime',
#  'every',
#  'will',
#  'sincere',
#  'becoming',
#  'show',
#  'go',
#  'front',
#  'either',
#  'amount',
#  'after',
#  'my',
#  'fire',
#  'done',
#  'its',
#  'before',
#  'namely',
#  'that',
#  'cannot',
#  'etc',
#  'these',
#  'of',
#  'thence',
#  'twenty',
#  'five',
#  'formerly',
#  'ie',
#  'over',
#  'six',
#  'yourselves',
#  'same',
#  'an',
#  'each',
#  're',
#  'thereafter',
#  'three',
#  'enough',
#  'most',
#  'thru',
#  'anyway',
#  'what',
#  'may',
#  'whoever',
#  'eleven',
#  'latterly',
#  'we',
#  'keep',
#  'seemed',
#  'back',
#  'ourselves',
#  'why',
#  'another',
#  'by',
#  'his',
#  'now',
#  'bottom',
#  'nevertheless',
#  'along',
#  'everything',
#  'couldnt',
#  'toward',
#  'fill']

# %% [markdown]
# <font size = "5">
#
# Create custom stop words

# %%
# Here we added Python to the list of stop words
custom_stop_words = list(ENGLISH_STOP_WORDS) + ["Python"]

# You can also create your own list
# custom_stop_words = ["and","or","how"]

# %% [markdown]
# <font size = "5">
#
# Count vectorizer
#
# - Check for distinct words across all reviews
# - Remove any stop words
# - ```min_df``` is used to filter out words depending <br>
# on how often they occur. For example, ```min_df=3``` <br>
# only keeps words if they are mentioned at least 3 times

# %%
word_model = CountVectorizer(min_df=1,
                       stop_words=custom_stop_words)
word_model.fit(reviews)
# Out:
# /Users/asanc31/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['python'] not in stop_words.
#   warnings.warn(
# CountVectorizer(stop_words=['cant', 'for', 'please', 'if', 'become', 'is',
#                             'mine', 'than', 'part', 'during', 'nor', 'third',
#                             'only', 'whole', 'amoungst', 'a', 'such',
#                             'hereafter', 'out', 'been', 'inc', 'interest',
#                             'thereby', 'nowhere', 'whereas', 'thick', 'whose',
#                             'detail', 'within', 'afterwards', ...])

# %% [markdown]
# <font size = "5">
#
# Check Vocabulary
#
# - Check in VS-Code Data Viewer
# - You can use preliminary findings to decide whether <br>
# to add more stop words

# %%
# document-term matrix
X = word_model.transform(reviews)

# frequencies
word_counts = X.sum(axis=0)
print(word_model.vocabulary_.items())


display(word_counts)

# map each word to its count
word_freq_dictionary = {word: int(word_counts[0, idx]) 
                         for word, idx in word_model.vocabulary_.items()}

frequency_words  = pd.DataFrame(word_freq_dictionary,
                               columns=['Word', 'Frequency'])

frequency_words
# Out:
# dict_items([('initially', 2968), ('trouble', 5711), ('deciding', 1534), ('paperwhite', 3975), ('voyage', 5957), ('reviews', 4707), ('said', 4784), ('thing', 5570), ('great', 2557), ('spending', 5200), ('money', 3634), ('fortunately', 2362), ('friends', 2390), ('owned', 3931), ('ended', 1942), ('buying', 940), ('basis', 675), ('models', 3618), ('300', 124), ('ppi', 4212), ('80', 224), ('dollar', 1758), ('jump', 3107), ('turns', 5745), ('pricey', 4260), ('page', 3949), ('press', 4246), ('isn', 3069), ('sensitive', 4893), ('fine', 2241), ('specific', 5190), ('setting', 4917), ('don', 1761), ('need', 3705), ('auto', 592), ('light', 3280), ('adjustment', 334), ('week', 6032), ('loving', 3395), ('regrets', 4555), ('touch', 5649), ('screen', 4841), ('receptive', 4495), ('easy', 1868), ('use', 5867), ('regardless', 4550), ('time', 5607), ('day', 1513), ('case', 1002), ('hard', 2637), ('change', 1047), ('ll', 3339), ('changing', 1052), ('level', 3261), ('certain', 1035), ('reading', 4459), ('glad', 2490), ('went', 6046), ('international', 3032), ('shipping', 4960), ('option', 3880), ('amazon', 427), ('extra', 2107), ('expense', 2072), ('delivery', 1575), ('tracking', 5665), ('didnt', 1634), ('worry', 6130), ('customs', 1478), ('used', 5869), ('party', 3999), ('service', 4911), ('allow', 411), ('preface', 4224), ('little', 3333), ('history', 2744), ('casual', 1008), ('reader', 4456), ('nook', 3764), ('simple', 5023), ('2011', 78), ('ve', 5904), ('read', 4452), ('harry', 2649), ('potter', 4205), ('series', 4904), ('girl', 2483), ('dragon', 1791), ('tattoo', 5499), ('1984', 60), ('brave', 853), ('new', 3733), ('world', 6124), ('key', 3134), ('titles', 5625), ('fair', 2138), ('say', 4812), ('did', 1632), ('gotten', 2529), ('theirs', 5558), ('fast', 2169), ('forward', 2364), ('today', 5627), ('kindle', 3154), ('admit', 338), ('love', 3389), ('just', 3116), ('let', 3256), ('relate', 4561), ('review', 4701), ('investment', 3053), ('139', 34), ('00', 0), ('experience', 2076), ('receive', 4487), ('buy', 937), ('simply', 5028), ('paying', 4012), ('entire', 1975), ('included', 2921), ('hunger', 2828), ('games', 2433), ('trilogy', 5706), ('shall', 4935), ('moving', 3657), ('divergent', 1733), ('soon', 5151), ('hindered', 2740), ('past', 4004), ('years', 6170), ('inspired', 2990), ('pick', 4083), ('hands', 2623), ('dive', 1732), ('feeling', 2199), ('oh', 3831), ('man', 3442), ('awesome', 623), ('desire', 1603), ('adore', 343), ('considering', 1314), ('purchasing', 4373), ('stop', 5295), ('thinking', 5573), ('downloaded', 1783), ('books', 814), ('ton', 5633), ('half', 2611), ('battery', 683), ('left', 3247), ('make', 3435), ('happy', 2636), ('inspire', 2989), ('inside', 2985), ('enjoying', 1960), ('far', 2161), ('original', 3894), ('2012', 79), ('eyes', 2113), ('hurt', 2831), ('long', 3366), ('haven', 2657), ('experienced', 2077), ('bought', 835), ('paperwhites', 3977), ('pleased', 4140), ('constant', 1322), ('companion', 1226), ('suppose', 5419), ('ive', 3084), ('average', 610), ('book', 809), ('days', 1515), ('wouldnt', 6138), ('youd', 6177), ('pry', 4355), ('cold', 1175), ('dead', 1517), ('fingers', 2246), ('sundry', 5399), ('logistical', 3361), ('reasons', 4479), ('good', 2517), ('amazons', 432), ('app', 478), ('iphone', 3059), ('naturally', 3688), ('cool', 1373), ('usability', 5862), ('delivers', 1574), ('works', 6122), ('attractions', 578), ('course', 1408), ('aspects', 545), ('like', 3291), ('critique', 1451), ('ah', 383), ('knew', 3168), ('coming', 1205), ('member', 3513), ('bookbub', 811), ('daily', 1489), ('list', 3317), ('alerts', 398), ('deals', 1521), ('chosen', 1106), ('genres', 2464), ('best', 734), ('theres', 5563), ('stuff', 5337), ('accumulative', 282), ('effect', 1898), ('number', 3793), ('actually', 306), ('creeping', 1445), ('upward', 5860), ('400', 151), ('mind', 3572), ('noticed', 3780), ('turning', 5744), ('remained', 4579), ('exactly', 2029), ('action', 295), ('positively', 4192), ('glacial', 2489), ('slow', 5085), ('think', ...
# matrix([[ 7, 20,  1, ...,  1,  1,  1]])
# Empty DataFrame
# Columns: [Word, Frequency]
# Index: []

# %%
# Extract words in vocabulary and frequency
vocabulary = word_model.vocabulary_

# Convert to dataframew
#frequency_words  = pd.DataFrame(vocabulary.items(),
#                                columns=['Word', 'Frequency'])
# frequency_words = pd.DataFrame(vocabulary.items())
frequency_words = pd.DataFrame(vocabulary.items()).reset_index()
frequency_words.columns = ['Frequency','Word', 'ID']
frequency_words

# Display sorted dataset                                
frequency_words.sort_values(by = "Frequency",ascending=False)
# Out:
#       Frequency        Word    ID
# 6194       6194   canceling   967
# 6193       6193     unhappy  5800
# 6192       6192    envelope  1977
# 6191       6191     mindful  3574
# 6190       6190     drained  1794
# ...         ...         ...   ...
# 4             4      voyage  5957
# 3             3  paperwhite  3975
# 2             2    deciding  1534
# 1             1     trouble  5711
# 0             0   initially  2968
#
# [6195 rows x 3 columns]

# %% [markdown]
# <font size = "5">
#
# Create a dataset counting which words are used <br>
# per review
#
# - Each row is a different review
# - Each column is a ${0,1}$ indicator on whether that <br>
# word was mentioned
# - Huge matrix!!

# %%
# Create X matrix
X = word_model.transform(reviews)

# Check dimension of X matrix
np.shape(X)

X_dataframe = pd.DataFrame(X)

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Create a bag of words for the column "review.title".
#
# - What are the most common words?

# %%
# Write your own code

# %% [markdown]
# # <span style="color:darkblue"> IV. Sentiment Analysis </span>
#
# <font size = "5">
# Sentiment analsys uses words to predict user ratings. <br>
#
#
# - In this case we have ratings labels
# - We'll use the data with nonmissing labels

# %%
# Write your own code

text = data_nonmissing["reviews.text"]
y    = data_nonmissing["reviews.rating"]

text_train, text_test, y_train, y_test = train_test_split(text, y,
                                                    random_state=0)

# %% [markdown]
# <font size = "5">
#
# Extract vectorized X

# %%
# Create X matrix
word_model_train = CountVectorizer(min_df=1,
                       stop_words=custom_stop_words)
word_model_train.fit(text_train)
X_train = word_model.transform(text_train)

# Check dimension of X matrix
np.shape(X)
# Out:
# /Users/asanc31/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['python'] not in stop_words.
#   warnings.warn(
# (1597, 6195)

# %% [markdown]
# <font size = "5">
#
# We can compress the data using <br>
# truncated singular value decomposition (SVD)
#
# - This is an alternative to PCA that is better suited <br>
# for sparse, binary data like text

# %%
svd = TruncatedSVD(n_components=3,random_state=42);
svd.fit(X_train)
X_svd_train = svd.transform(X_train)
np.shape(X_svd_train)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# (882, 3)

# %%
# Hue is used to color
ax = sns.scatterplot(x = X_svd_train[:,0],
                     y = y_train)
ax.set(xlabel='First Principal Component',
       ylabel='Second Principal Component')
# Out:
# [Text(0.5, 0, 'First Principal Component'),
#  Text(0, 0.5, 'Second Principal Component')]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Create a machine learning pipeline
#
# - Run a support vector machine regression to predict user ratings
# - What is the out-of-sample performance on the test data?
# - Use your data to predict reviews that were missing
# - How does the distribution of missing to non-missing reviews compare?

# %%
# Write your own code

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - What happens if you change the minimum frequency of words <br>
# and/or change the number of components?

# %%
# Write your own code
