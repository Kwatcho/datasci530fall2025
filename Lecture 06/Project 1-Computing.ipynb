# %%
import pandas as pd
from selenium import webdriver

# %%
exec(open("./scripts/import_packages.py").read())

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

# %%
options = webdriver.ChromeOptions()

# %%
# User parameters 
ORIGIN = "ATL"            
DEST = "RDU"   
DEPART_DATE = "11-10-2025"

# %%
starting_url = 'https://www.delta.com/flightsearch/book-a-flight'
driver.get(starting_url)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 starting_url = 'https://www.delta.com/flightsearch/book-a-flight'
# ----> 2 driver.get(starting_url)
#
# File c:\Users\kwatcho\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.get(self, url)
#     352 def get(self, url: str) -> None:
#     353     """Loads a web page in the current browser session."""
# --> 354     self.execute(Command.GET, {"url": url})
#
# File c:\Users\kwatcho\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File c:\Users\kwatcho\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 	GetHandleVerifier [0x0x9ec333+65459]
# 	GetHandleVerifier [0x0x9ec374+65524]
# 	(No symbol) [0x0x80d7c0]
# 	(No symbol) [0x0x84a663]
# 	(No symbol) [0x0x879cb6]
# 	(No symbol) [0x0x87555e]
# 	(No symbol) [0x0x874ad3]
# 	(No symbol) [0x0x7de73d]
# 	(No symbol) [0x0x7decbe]
# 	(No symbol) [0x0x7df15d]
# 	GetHandleVerifier [0x0xc6eda3+2697763]
# 	GetHandleVerifier [0x0xc69ec7+2677575]
# 	GetHandleVerifier [0x0xa14194+228884]
# 	GetHandleVerifier [0x0xa049f8+165496]
# 	GetHandleVerifier [0x0xa0b18d+192013]
# 	(No symbol) [0x0x7de3f2]
# 	(No symbol) [0x0x7ddb72]
# 	GetHandleVerifier [0x0xdc340c+4092044]
# 	BaseThreadInitThunk [0x0x757a7ba9+25]
# 	RtlInitializeExceptionChain [0x0x7735c3ab+107]
# 	RtlClearBits [0x0x7735c32f+191]
